# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishmakam/LDP/blob/master/LDP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import matplotlib
from sklearn.model_selection import train_test_split

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My\ Drive/LDP
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/LDP

# %%
df=pd.read_csv('train/application_train.csv')
# df.describe(include='all')

# %%
labels=['Defaulted','Repaid']
values=[(df['TARGET']==1).sum(),(df['TARGET']==0).sum()]
matplotlib.pyplot.pie(x=values,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0d73540b70>,
# ...
#  [Text(1.064812328126121, 0.2759976555527784, 'Defaulted'),
#   Text(-1.064812334586312, -0.27599763062904703, 'Repaid')],
#  [Text(0.5808067244324295, 0.15054417575606094, '8.1%'),
#   Text(-0.5808067279561702, -0.15054416216129834, '91.9%')])

# %%
y=df['TARGET']
df.drop(['TARGET'],axis=1)
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.33, random_state=42)

# %%
values_train=[list(y_train).count(1),list(y_train).count(0)]
matplotlib.pyplot.pie(values_train,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0d710532b0>,
# ...
#  [Text(1.0644948189173347, 0.27721973324089194, 'Defaulted'),
#   Text(-1.0644948254061306, -0.2772197083245922, 'Repaid')],
#  [Text(0.5806335375912733, 0.15121076358594104, '8.1%'),
#   Text(-0.5806335411306166, -0.15121074999523207, '91.9%')])

# %%
values_test=[list(y_test).count(1),list(y_test).count(0)]
matplotlib.pyplot.pie(values_test,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0d71009518>,
# ...
#  [Text(1.0654526577141195, 0.2735153271206563, 'Defaulted'),
#   Text(-1.0654526577141195, -0.27351532712065607, 'Repaid')],
#  [Text(0.5811559951167923, 0.14919017842944887, '8.0%'),
#   Text(-0.5811559951167924, -0.14919017842944876, '92.0%')])
